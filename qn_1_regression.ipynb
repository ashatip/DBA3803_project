# %%
import pandas as pd 
df = pd.read_csv("data_static.csv")

# drop empty columns
df = df.dropna(axis=1, how='all')

# drop columns with few to no unique values 
for col in df.columns:
    if col != 'Worldscope Permanent ID' and col!= 'DS_CODE' and len(df[col].unique()) <= 100:
        df.drop(col,inplace=True,axis=1)

# drop columns with too many unique values 
for col in df.columns:
    if col != 'Worldscope Permanent ID' and col!= 'DS_CODE' and len(df[col].unique()) >= 1230:
        df.drop(col,inplace=True,axis=1)

# %%
# drop columns that are categorical 
non_floats = []
for col in df:
    if df[col].dtypes != "float64":
        non_floats.append(col)
df = df.drop(columns=non_floats)
df.columns
# Out:
# Index(['Alpha (Security)', 'Beta (WS)',
#        'Book Value Per Share - Current (Security)',
#        'Cash Flow Per Share - Current (Security)',
#        'Closely Held Shares - Current', 'Common / Ordinary Shareholders',
#        'Common Shares Outstanding - Current (Security)',
#        'Date Of Closely Held Shares', 'Date Of Common/Ordinary Shareholders',
#        'Date Of Current Price (Security)', 'Date Of Incorporation',
#        'Dividend Payout Per Share - Current (Security)',
#        'Dividend Yield - Current (Security)',
#        'Dividends Per Share - Last 12 Months (Security)',
#        'EPS - Last 12 Months (Security)',
#        'Earnings Yield - Current (Security)',
#        'Earnings Yield - Current High (Security)',
#        'Earnings Yield - Current Low (Security)', 'Inactive Date (Security)',
#        'Indicated Dividend Rate (Security)',
#        'Industry Classification Benchmark',
#        'Market Capitalisation (Public) - Current',
#        'Market Capitalisation - Current (Security)',
#        'Market Capitalization Current (U.S.$)',
#        'Market Price - Current (Security)',
#        'Market Price - Year To Date - High (Security)',
#        'Market Price - Year To Date - Low (Security)',
#        'Market Price 52 Week High', 'Market Price 52 Week Low',
#        'Price Trend - 13 Weeks (Security)',
#        'Price Trend - 52 Weeks (Security)',
#        'Price Trend - Four Week (Security)',
#        'Price Trend - Last Week (Security)',
#        'Price Trend - Previous Quarter (Security)',
#        'Price Trend - Quarter-To-Date (Security)',
#        'Price Trend - Year-To-Date (Security)', 'Price Trend 26 Weeks',
#        'Price/Book Value Ratio - Current (Security)',
#        'Price/Cash Flow Current (Security)',
#        'Price/Earnings Ratio - Current (Security)',
#        'Price/Earnings Ratio - Current High (Security)',
#        'Price/Earnings Ratio - Current Low (Security)',
#        'Reinvestment Rate - Per Share - Current',
#        'Return On Equity - Per Share - Current', 'SIC Code 6', 'Sic Code 2',
#        'Sic Code 3', 'Sic Code 4', 'Sic Code 5',
#        'Thomson Reuters Business Classification Code'],
#       dtype='object')

# %%
# dropping irrelevant columns:  
df = df.drop(['Thomson Reuters Business Classification Code', 'SIC Code 6', 'Sic Code 2',
       'Sic Code 3', 'Sic Code 4', 'Sic Code 5', 'Date Of Closely Held Shares', 
        'Date Of Common/Ordinary Shareholders', 'Date Of Current Price (Security)',
        'Date Of Incorporation', 'Inactive Date (Security)', 'Industry Classification Benchmark'], axis=1)
df.columns
# Out:
# Index(['Alpha (Security)', 'Beta (WS)',
#        'Book Value Per Share - Current (Security)',
#        'Cash Flow Per Share - Current (Security)',
#        'Closely Held Shares - Current', 'Common / Ordinary Shareholders',
#        'Common Shares Outstanding - Current (Security)',
#        'Dividend Payout Per Share - Current (Security)',
#        'Dividend Yield - Current (Security)',
#        'Dividends Per Share - Last 12 Months (Security)',
#        'EPS - Last 12 Months (Security)',
#        'Earnings Yield - Current (Security)',
#        'Earnings Yield - Current High (Security)',
#        'Earnings Yield - Current Low (Security)',
#        'Indicated Dividend Rate (Security)',
#        'Market Capitalisation (Public) - Current',
#        'Market Capitalisation - Current (Security)',
#        'Market Capitalization Current (U.S.$)',
#        'Market Price - Current (Security)',
#        'Market Price - Year To Date - High (Security)',
#        'Market Price - Year To Date - Low (Security)',
#        'Market Price 52 Week High', 'Market Price 52 Week Low',
#        'Price Trend - 13 Weeks (Security)',
#        'Price Trend - 52 Weeks (Security)',
#        'Price Trend - Four Week (Security)',
#        'Price Trend - Last Week (Security)',
#        'Price Trend - Previous Quarter (Security)',
#        'Price Trend - Quarter-To-Date (Security)',
#        'Price Trend - Year-To-Date (Security)', 'Price Trend 26 Weeks',
#        'Price/Book Value Ratio - Current (Security)',
#        'Price/Cash Flow Current (Security)',
#        'Price/Earnings Ratio - Current (Security)',
#        'Price/Earnings Ratio - Current High (Security)',
#        'Price/Earnings Ratio - Current Low (Security)',
#        'Reinvestment Rate - Per Share - Current',
#        'Return On Equity - Per Share - Current'],
#       dtype='object')

# %%
# analyzing columns that appear to be similar and removing 'duplicates'
newdf = df.filter(like='Dividend', axis=1)
newdf.head(25)
# Out:
#     Dividend Payout Per Share - Current (Security)  \
# 0                                             5.13
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                             0.00
# 5                                              NaN
# 6                                             0.00
# 7                                             0.00
# 8                                              NaN
# 9                                             0.00
# 10                                           55.10
# 11                                            0.00
# 12                                             NaN
# 13                                             NaN
# 14                                           14.95
# 15                                           57.83
# 16                                            0.00
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                           34.71
# 21                                             NaN
# 22                                            0.00
# 23                                           17.71
# 24                                             NaN
#
#     Dividend Yield - Current (Security)  \
# 0                                  1.77
# 1                                  2.45
# 2                                   NaN
# 3                                   NaN
# 4                                  0.00
# 5                                   NaN
# 6                                  0.00
# 7                                  0.00
# 8                                  4.07
# 9                                  0.00
# 10                                 1.74
# 11                                 0.00
# 12                                  NaN
# 13                                  NaN
# 14                                 1.89
# 15                                 3.51
# 16                                 0.00
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                 2.01
# 21                                  NaN
# 22                                 0.00
# 23                                 0.62
# 24                                  NaN
#
#     Dividends Per Share - Last 12 Months (Security)  \
# 0                                             0.010
# 1                                             0.012
# 2                                               NaN
# 3                                             0.000
# 4                                             0.000
# 5                                               NaN
# 6                                             0.000
# 7                                             0.000
# 8                                             0.025
# 9                                             0.000
# 10                                            0.022
# 11                                            0.000
# 12                                              NaN
# 13                                              NaN
# 14                                            0.005
# 15                                            0.042
# 16                                            0.000
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                           12.000
# 21                                              NaN
# 22                                            0.000
# 23                                            0.002
# 24                                              NaN
#
#     Indicated Dividend Rate (Security)
# 0                                0.010
# 1                                0.012
# 2                                  NaN
# 3                                0.000
# 4                                0.000
# 5                                  NaN
# 6                                0.000
# 7                                0.000
# 8                                0.025
# 9                                0.000
# 10                               0.022
# 11                               0.000
# 12                                 NaN
# 13                                 NaN
# 14                               0.005
# 15                               0.042
# 16                               0.000
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                              12.000
# 21                                 NaN
# 22                               0.000
# 23                               0.002
# 24                                 NaN

# %% [markdown]
# Since 'Dividends Per Share - Last 12 Months (Security)' and 'Indicated Dividend Rate (Security)' appear to be similar, we will drop one of them.

# %%
df = df.drop(['Dividends Per Share - Last 12 Months (Security)'], axis=1)
newdf = df.filter(like='Earnings', axis=1)
newdf.head(25)
# Out:
#     Earnings Yield - Current (Security)  \
# 0                                 34.50
# 1                                 -6.13
# 2                                   NaN
# 3                                   NaN
# 4                                 -5.56
# 5                                   NaN
# 6                                -27.41
# 7                                 21.55
# 8                                 -3.06
# 9                                  3.21
# 10                                 3.16
# 11                                -9.43
# 12                                  NaN
# 13                                  NaN
# 14                                12.62
# 15                                 6.07
# 16                              -229.89
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                 5.79
# 21                                  NaN
# 22                               -17.45
# 23                                 3.47
# 24                                  NaN
#
#     Earnings Yield - Current High (Security)  \
# 0                                      33.04
# 1                                      -4.55
# 2                                        NaN
# 3                                        NaN
# 4                                      -3.77
# 5                                        NaN
# 6                                     -23.78
# 7                                      19.61
# 8                                      -1.89
# 9                                       2.72
# 10                                      3.16
# 11                                     -7.33
# 12                                       NaN
# 13                                       NaN
# 14                                     10.97
# 15                                      5.39
# 16                                    -74.03
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                      5.67
# 21                                       NaN
# 22                                    -16.20
# 23                                      3.09
# 24                                       NaN
#
#     Earnings Yield - Current Low (Security)  \
# 0                                     72.20
# 1                                     -6.68
# 2                                       NaN
# 3                                       NaN
# 4                                     -6.97
# 5                                       NaN
# 6                                    -33.34
# 7                                     22.60
# 8                                     -3.45
# 9                                     21.20
# 10                                     5.87
# 11                                   -16.50
# 12                                      NaN
# 13                                      NaN
# 14                                    13.12
# 15                                     8.20
# 16                                  -728.00
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                    10.21
# 21                                      NaN
# 22                                   -24.05
# 23                                     4.26
# 24                                      NaN
#
#     Price/Earnings Ratio - Current (Security)  \
# 0                                        2.90
# 1                                      -16.31
# 2                                         NaN
# 3                                         NaN
# 4                                      -18.00
# 5                                         NaN
# 6                                       -3.65
# 7                                        4.64
# 8                                      -32.68
# 9                                       31.13
# 10                                      31.68
# 11                                     -10.61
# 12                                        NaN
# 13                                        NaN
# 14                                       7.92
# 15                                      16.48
# 16                                      -0.43
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                      17.26
# 21                                        NaN
# 22                                      -5.73
# 23                                      28.79
# 24                                        NaN
#
#     Price/Earnings Ratio - Current High (Security)  \
# 0                                             3.03
# 1                                           -21.96
# 2                                              NaN
# 3                                              NaN
# 4                                           -26.52
# 5                                              NaN
# 6                                            -4.20
# 7                                             5.10
# 8                                           -52.87
# 9                                            36.79
# 10                                           31.68
# 11                                          -13.64
# 12                                             NaN
# 13                                             NaN
# 14                                            9.12
# 15                                           18.56
# 16                                           -1.35
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                           17.63
# 21                                             NaN
# 22                                           -6.17
# 23                                           32.33
# 24                                             NaN
#
#     Price/Earnings Ratio - Current Low (Security)
# 0                                            1.39
# 1                                          -14.98
# 2                                             NaN
# 3                                             NaN
# 4                                          -14.34
# 5                                             NaN
# 6                                           -3.00
# 7                                            4.42
# 8                                          -28.96
# 9                                            4.72
# 10                                          17.03
# 11                                          -6.06
# 12                                            NaN
# 13                                            NaN
# 14                                           7.62
# 15                                          12.19
# 16                                          -0.14
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                           9.80
# 21                                            NaN
# 22                                          -4.16
# 23                                          23.47
# 24                                            NaN

# %%
newdf = df.filter(like='Market', axis=1)
newdf.head(25)
# Out:
#     Market Capitalisation (Public) - Current  \
# 0                               1.914500e+04
# 1                               2.398940e+05
# 2                                        NaN
# 3                                        NaN
# 4                               6.919000e+03
# 5                                        NaN
# 6                               8.807000e+03
# 7                               4.082800e+04
# 8                               5.420300e+04
# 9                               6.605000e+03
# 10                              5.585830e+05
# 11                              7.608000e+03
# 12                                       NaN
# 13                                       NaN
# 14                              4.447900e+04
# 15                              5.598300e+04
# 16                              2.836000e+03
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                              2.085327e+09
# 21                                       NaN
# 22                              1.255500e+06
# 23                              1.499100e+04
# 24                                       NaN
#
#     Market Capitalisation - Current (Security)  \
# 0                                 2.443100e+04
# 1                                 3.847900e+05
# 2                                          NaN
# 3                                          NaN
# 4                                 4.069600e+04
# 5                                          NaN
# 6                                 8.829000e+03
# 7                                 6.787000e+04
# 8                                 1.247700e+05
# 9                                 1.141400e+04
# 10                                1.408600e+06
# 11                                1.449600e+04
# 12                                         NaN
# 13                                         NaN
# 14                                1.096610e+05
# 15                                2.248180e+05
# 16                                6.611000e+03
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                2.121417e+09
# 21                                         NaN
# 22                                2.199397e+06
# 23                                3.991200e+04
# 24                                         NaN
#
#     Market Capitalization Current (U.S.$)  Market Price - Current (Security)  \
# 0                                 17157.0                              0.565
# 1                                270219.0                              0.490
# 2                                     NaN                              0.005
# 3                                     NaN                                NaN
# 4                                 28579.0                              0.133
# 5                                     NaN                                NaN
# 6                                  6200.0                              0.590
# 7                                 47662.0                              0.965
# 8                                 87620.0                              0.615
# 9                                  8016.0                              0.033
# 10                               989190.0                              1.265
# 11                                10180.0                              0.007
# 12                                    NaN                                NaN
# 13                                    NaN                                NaN
# 14                                77009.0                              0.265
# 15                               157878.0                              1.203
# 16                                 4643.0                              0.019
# 17                                    NaN                                NaN
# 18                                    NaN                              0.740
# 19                                    NaN                              0.030
# 20                             19220035.0                            596.700
# 21                                    NaN                              0.395
# 22                               283546.0                              0.910
# 23                                28028.0                              0.325
# 24                                    NaN                                NaN
#
#     Market Price - Year To Date - High (Security)  \
# 0                                           0.590
# 1                                           0.660
# 2                                           0.015
# 3                                             NaN
# 4                                           0.196
# 5                                             NaN
# 6                                           0.680
# 7                                           1.060
# 8                                           0.995
# 9                                           0.039
# 10                                          1.265
# 11                                          0.009
# 12                                            NaN
# 13                                            NaN
# 14                                          0.305
# 15                                          1.354
# 16                                          0.059
# 17                                            NaN
# 18                                          0.760
# 19                                          0.070
# 20                                        609.400
# 21                                          0.415
# 22                                          0.980
# 23                                          0.365
# 24                                            NaN
#
#     Market Price - Year To Date - Low (Security)  Market Price 52 Week High  \
# 0                                          0.270                      0.590
# 1                                          0.450                      0.660
# 2                                          0.005                      0.015
# 3                                            NaN                        NaN
# 4                                          0.106                      0.196
# 5                                            NaN                      0.945
# 6                                          0.485                      0.680
# 7                                          0.920                      1.405
# 8                                          0.545                      1.000
# 9                                          0.005                      0.052
# 10                                         0.680                      1.265
# 11                                         0.004                      0.009
# 12                                           NaN                      1.010
# 13                                           NaN                      1.010
# 14                                         0.255                      0.305
# 15                                         0.889                      1.354
# 16                                         0.006                      0.059
# 17                                           NaN                        NaN
# 18                                         0.390                        NaN
# 19                                         0.025                      0.070
# 20                                       338.800                    771.200
# 21                                         0.275                      0.415
# 22                                         0.660                      0.980
# 23                                         0.265                      0.365
# 24                                           NaN                      0.500
#
#     Market Price 52 Week Low
# 0                      0.250
# 1                      0.450
# 2                      0.005
# 3                        NaN
# 4                      0.101
# 5                      0.670
# 6                      0.380
# 7                      0.920
# 8                      0.545
# 9                      0.005
# 10                     0.680
# 11                     0.004
# 12                     0.230
# 13                     0.765
# 14                     0.255
# 15                     0.889
# 16                     0.006
# 17                       NaN
# 18                       NaN
# 19                     0.025
# 20                   338.800
# 21                     0.255
# 22                     0.660
# 23                     0.182
# 24                     0.300

# %% [markdown]
# Since 'Market Price - Year To Date - High (Security)' and 'Market Price 52 Week High' appear to be similar, we will drop one of them.
# Since 'Market Price - Year To Date - Low (Security)' and 'Market Price 52 Week Low' appear to be similar, we will drop one of them.

# %%
df = df.drop(['Market Price - Year To Date - High (Security)', 'Market Price - Year To Date - Low (Security)'], axis=1)
newdf = df.filter(like='Price', axis=1)
newdf.head(25)
# Out:
#     Market Price - Current (Security)  Market Price 52 Week High  \
# 0                               0.565                      0.590
# 1                               0.490                      0.660
# 2                               0.005                      0.015
# 3                                 NaN                        NaN
# 4                               0.133                      0.196
# 5                                 NaN                      0.945
# 6                               0.590                      0.680
# 7                               0.965                      1.405
# 8                               0.615                      1.000
# 9                               0.033                      0.052
# 10                              1.265                      1.265
# 11                              0.007                      0.009
# 12                                NaN                      1.010
# 13                                NaN                      1.010
# 14                              0.265                      0.305
# 15                              1.203                      1.354
# 16                              0.019                      0.059
# 17                                NaN                        NaN
# 18                              0.740                        NaN
# 19                              0.030                      0.070
# 20                            596.700                    771.200
# 21                              0.395                      0.415
# 22                              0.910                      0.980
# 23                              0.325                      0.365
# 24                                NaN                      0.500
#
#     Market Price 52 Week Low  Price Trend - 13 Weeks (Security)  \
# 0                      0.250                              18.95
# 1                      0.450                              -3.92
# 2                      0.005                                NaN
# 3                        NaN                                NaN
# 4                      0.101                                NaN
# 5                      0.670                              17.95
# 6                      0.380                               2.61
# 7                      0.920                              -4.93
# 8                      0.545                               7.89
# 9                      0.005                                NaN
# 10                     0.680                              65.36
# 11                     0.004                              16.67
# 12                     0.230                              56.69
# 13                     0.765                                NaN
# 14                     0.255                              -7.02
# 15                     0.889                               3.83
# 16                     0.006                              58.33
# 17                       NaN                                NaN
# 18                       NaN                                NaN
# 19                     0.025                                NaN
# 20                   338.800                              30.31
# 21                     0.255                                NaN
# 22                     0.660                              15.19
# 23                     0.182                               0.00
# 24                     0.300                                NaN
#
#     Price Trend - 52 Weeks (Security)  Price Trend - Four Week (Security)  \
# 0                              109.26                               13.00
# 1                              -22.83                                6.52
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                               15.65                                 NaN
# 5                               35.29                                2.22
# 6                               49.37                                 NaN
# 7                              -15.72                               -1.03
# 8                              -38.19                               -6.11
# 9                              -32.65                              230.00
# 10                              46.24                               48.82
# 11                             -12.50                                0.00
# 12                             255.36                               25.95
# 13                                NaN                                 NaN
# 14                             -10.17                               -1.85
# 15                               3.81                                2.11
# 16                             -64.81                               18.75
# 17                                NaN                                 NaN
# 18                                NaN                                 NaN
# 19                                NaN                                 NaN
# 20                             -22.36                               22.20
# 21                                NaN                                 NaN
# 22                               3.41                               10.98
# 23                              47.73                               -1.52
# 24                                NaN                                 NaN
#
#     Price Trend - Last Week (Security)  \
# 0                                -3.42
# 1                                 2.08
# 2                                  NaN
# 3                                  NaN
# 4                                -6.34
# 5                                -0.54
# 6                                -5.60
# 7                                -2.53
# 8                                -1.60
# 9                                -5.71
# 10                                0.40
# 11                                0.00
# 12                                8.15
# 13                                 NaN
# 14                                0.00
# 15                               -1.02
# 16                              -17.39
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                5.80
# 21                                 NaN
# 22                               10.98
# 23                               -7.14
# 24                                 NaN
#
#     Price Trend - Previous Quarter (Security)  \
# 0                                        3.03
# 1                                      -20.83
# 2                                      -50.00
# 3                                       -3.56
# 4                                       15.04
# 5                                       10.64
# 6                                        5.93
# 7                                       -9.00
# 8                                      -14.07
# 9                                       28.57
# 10                                      -3.64
# 11                                       0.00
# 12                                      80.22
# 13                                       4.26
# 14                                       3.57
# 15                                       0.54
# 16                                     -59.38
# 17                                      33.04
# 18                                      32.32
# 19                                      33.33
# 20                                      22.15
# 21                                      -1.23
# 22                                      10.81
# 23                                      22.92
# 24                                      15.15
#
#     Price Trend - Quarter-To-Date (Security)  \
# 0                                      10.78
# 1                                       3.16
# 2                                        NaN
# 3                                        NaN
# 4                                       2.31
# 5                                      17.95
# 6                                      -5.60
# 7                                       0.52
# 8                                       6.03
# 9                                     -26.67
# 10                                     59.12
# 11                                     16.67
# 12                                     21.34
# 13                                       NaN
# 14                                     -8.62
# 15                                      0.85
# 16                                     46.15
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                     33.76
# 21                                       NaN
# 22                                     10.98
# 23                                     10.17
# 24                                       NaN
#
#     Price Trend - Year-To-Date (Security)  Price Trend 26 Weeks  \
# 0                                   88.33                13.000
# 1                                  -13.27               -10.092
# 2                                     NaN                   NaN
# 3                                     NaN                   NaN
# 4                                   10.83                11.765
# 5                                   17.95                28.671
# 6                                   13.46                 3.509
# 7                                  -11.87                -8.095
# 8                                  -34.92               -18.000
# 9                                  -21.43                10.000
# 10                                  50.60                47.953
# 11                                  16.67                 0.000
# 12                                 298.00               176.389
# 13                                    NaN                   NaN
# 14                                 -13.11                -8.621
# 15                                   9.05                -2.760
# 16                                 -66.67               -54.762
# 17                                    NaN                   NaN
# 18                                    NaN                   NaN
# 19                                    NaN                   NaN
# 20                                 -12.13                28.544
# 21                                    NaN                   NaN
# 22                                  15.19                19.737
# 23                                  58.54                64.975
# 24                                    NaN                   NaN
#
#     Price/Book Value Ratio - Current (Security)  \
# 0                                          0.97
# 1                                          0.48
# 2                                           NaN
# 3                                           NaN
# 4                                          1.05
# 5                                           NaN
# 6                                          0.41
# 7                                          0.51
# 8                                          0.55
# 9                                          0.32
# 10                                         2.65
# 11                                         3.85
# 12                                          NaN
# 13                                          NaN
# 14                                         0.43
# 15                                         0.44
# 16                                         0.35
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                         0.78
# 21                                          NaN
# 22                                         0.51
# 23                                         0.57
# 24                                          NaN
#
#     Price/Cash Flow Current (Security)  \
# 0                                 3.13
# 1                                 5.32
# 2                                  NaN
# 3                                  NaN
# 4                               -19.05
# 5                                  NaN
# 6                                -5.32
# 7                                 5.59
# 8                               197.12
# 9                                -6.47
# 10                               20.00
# 11                              -17.95
# 12                                 NaN
# 13                                 NaN
# 14                              182.76
# 15                                2.97
# 16                               -1.08
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                               -4.23
# 21                                 NaN
# 22                               -3.50
# 23                                1.59
# 24                                 NaN
#
#     Price/Earnings Ratio - Current (Security)  \
# 0                                        2.90
# 1                                      -16.31
# 2                                         NaN
# 3                                         NaN
# 4                                      -18.00
# 5                                         NaN
# 6                                       -3.65
# 7                                        4.64
# 8                                      -32.68
# 9                                       31.13
# 10                                      31.68
# 11                                     -10.61
# 12                                        NaN
# 13                                        NaN
# 14                                       7.92
# 15                                      16.48
# 16                                      -0.43
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                      17.26
# 21                                        NaN
# 22                                      -5.73
# 23                                      28.79
# 24                                        NaN
#
#     Price/Earnings Ratio - Current High (Security)  \
# 0                                             3.03
# 1                                           -21.96
# 2                                              NaN
# 3                                              NaN
# 4                                           -26.52
# 5                                              NaN
# 6                                            -4.20
# 7                                             5.10
# 8                                           -52.87
# 9                                            36.79
# 10                                           31.68
# 11                                          -13.64
# 12                                             NaN
# 13                                             NaN
# 14                                            9.12
# 15                                           18.56
# 16                                           -1.35
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                           17.63
# 21                                             NaN
# 22                                           -6.17
# 23                                           32.33
# 24                                             NaN
#
#     Price/Earnings Ratio - Current Low (Security)
# 0                                            1.39
# 1                                          -14.98
# 2                                             NaN
# 3                                             NaN
# 4                                          -14.34
# 5                                             NaN
# 6                                           -3.00
# 7                                            4.42
# 8                                          -28.96
# 9                                            4.72
# 10                                          17.03
# 11                                          -6.06
# 12                                            NaN
# 13                                            NaN
# 14                                           7.62
# 15                                          12.19
# 16                                          -0.14
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                           9.80
# 21                                            NaN
# 22                                          -4.16
# 23                                          23.47
# 24                                            NaN

# %%
df.to_csv('testing regression')

# %%
df.columns
# Out:
# Index(['Alpha (Security)', 'Beta (WS)',
#        'Book Value Per Share - Current (Security)',
#        'Cash Flow Per Share - Current (Security)',
#        'Closely Held Shares - Current', 'Common / Ordinary Shareholders',
#        'Common Shares Outstanding - Current (Security)',
#        'Dividend Payout Per Share - Current (Security)',
#        'Dividend Yield - Current (Security)',
#        'EPS - Last 12 Months (Security)',
#        'Earnings Yield - Current (Security)',
#        'Earnings Yield - Current High (Security)',
#        'Earnings Yield - Current Low (Security)',
#        'Indicated Dividend Rate (Security)',
#        'Market Capitalisation (Public) - Current',
#        'Market Capitalisation - Current (Security)',
#        'Market Capitalization Current (U.S.$)',
#        'Market Price - Current (Security)', 'Market Price 52 Week High',
#        'Market Price 52 Week Low', 'Price Trend - 13 Weeks (Security)',
#        'Price Trend - 52 Weeks (Security)',
#        'Price Trend - Four Week (Security)',
#        'Price Trend - Last Week (Security)',
#        'Price Trend - Previous Quarter (Security)',
#        'Price Trend - Quarter-To-Date (Security)',
#        'Price Trend - Year-To-Date (Security)', 'Price Trend 26 Weeks',
#        'Price/Book Value Ratio - Current (Security)',
#        'Price/Cash Flow Current (Security)',
#        'Price/Earnings Ratio - Current (Security)',
#        'Price/Earnings Ratio - Current High (Security)',
#        'Price/Earnings Ratio - Current Low (Security)',
#        'Reinvestment Rate - Per Share - Current',
#        'Return On Equity - Per Share - Current'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 35

# %%
# keep only certain columns because we don't want the model equation to be too big 
# we choose 'Indicated Dividend Rate (Security)' to be our Y 
newdf = df[['Indicated Dividend Rate (Security)',
        'Alpha (Security)', 'Beta (WS)',
       'Book Value Per Share - Current (Security)',
       'Cash Flow Per Share - Current (Security)',
         'Earnings Yield - Current (Security)',
        'Market Capitalization Current (U.S.$)',
        'Market Price - Current (Security)',
        'Price/Book Value Ratio - Current (Security)',
       'Price/Cash Flow Current (Security)',
       'Price/Earnings Ratio - Current (Security)',
        'Return On Equity - Per Share - Current']]

# %%
# checking correlations between dependent variables 
print(newdf.corr())
# Out:
#                                              Indicated Dividend Rate (Security)  \
# Indicated Dividend Rate (Security)                                     1.000000
# Alpha (Security)                                                       0.006553
# Beta (WS)                                                              0.008587
# Book Value Per Share - Current (Security)                              0.762242
# Cash Flow Per Share - Current (Security)                               0.883698
# Earnings Yield - Current (Security)                                    0.012853
# Market Capitalization Current (U.S.$)                                  0.208598
# Market Price - Current (Security)                                      0.943762
# Price/Book Value Ratio - Current (Security)                            0.006903
# Price/Cash Flow Current (Security)                                     0.007677
# Price/Earnings Ratio - Current (Security)                              0.006960
# Return On Equity - Per Share - Current                                 0.023207
#
#                                              Alpha (Security)  Beta (WS)  \
# Indicated Dividend Rate (Security)                   0.006553   0.008587
# Alpha (Security)                                     1.000000  -0.266548
# Beta (WS)                                           -0.266548   1.000000
# Book Value Per Share - Current (Security)           -0.018409   0.006733
# Cash Flow Per Share - Current (Security)             0.007270   0.022788
# Earnings Yield - Current (Security)                  0.147367  -0.070206
# Market Capitalization Current (U.S.$)                0.020969   0.030873
# Market Price - Current (Security)                   -0.004778   0.004430
# Price/Book Value Ratio - Current (Security)          0.214107  -0.042802
# Price/Cash Flow Current (Security)                   0.022064  -0.111694
# Price/Earnings Ratio - Current (Security)            0.069407  -0.057886
# Return On Equity - Per Share - Current               0.074413  -0.126593
#
#                                              Book Value Per Share - Current (Security)  \
# Indicated Dividend Rate (Security)                                            0.762242
# Alpha (Security)                                                             -0.018409
# Beta (WS)                                                                     0.006733
# Book Value Per Share - Current (Security)                                     1.000000
# Cash Flow Per Share - Current (Security)                                      0.658653
# Earnings Yield - Current (Security)                                           0.017909
# Market Capitalization Current (U.S.$)                                         0.127443
# Market Price - Current (Security)                                             0.908427
# Price/Book Value Ratio - Current (Security)                                   0.001299
# Price/Cash Flow Current (Security)                                            0.004283
# Price/Earnings Ratio - Current (Security)                                     0.006082
# Return On Equity - Per Share - Current                                        0.010319
#
#                                              Cash Flow Per Share - Current (Security)  \
# Indicated Dividend Rate (Security)                                           0.883698
# Alpha (Security)                                                             0.007270
# Beta (WS)                                                                    0.022788
# Book Value Per Share - Current (Security)                                    0.658653
# Cash Flow Per Share - Current (Security)                                     1.000000
# Earnings Yield - Current (Security)                                          0.013451
# Market Capitalization Current (U.S.$)                                        0.173123
# Market Price - Current (Security)                                            0.861247
# Price/Book Value Ratio - Current (Security)                                  0.005900
# Price/Cash Flow Current (Security)                                           0.008786
# Price/Earnings Ratio - Current (Security)                                    0.006297
# Return On Equity - Per Share - Current                                       0.008418
#
#                                              Earnings Yield - Current (Security)  \
# Indicated Dividend Rate (Security)                                      0.012853
# Alpha (Security)                                                        0.147367
# Beta (WS)                                                              -0.070206
# Book Value Per Share - Current (Security)                               0.017909
# Cash Flow Per Share - Current (Security)                                0.013451
# Earnings Yield - Current (Security)                                     1.000000
# Market Capitalization Current (U.S.$)                                   0.045392
# Market Price - Current (Security)                                       0.014514
# Price/Book Value Ratio - Current (Security)                             0.020019
# Price/Cash Flow Current (Security)                                      0.025738
# Price/Earnings Ratio - Current (Security)                               0.009879
# Return On Equity - Per Share - Current                                  0.090090
#
#                                              Market Capitalization Current (U.S.$)  \
# Indicated Dividend Rate (Security)                                        0.208598
# Alpha (Security)                                                          0.020969
# Beta (WS)                                                                 0.030873
# Book Value Per Share - Current (Security)                                 0.127443
# Cash Flow Per Share - Current (Security)                                  0.173123
# Earnings Yield - Current (Security)                                       0.045392
# Market Capitalization Current (U.S.$)                                     1.000000
# Market Price - Current (Security)                                         0.136397
# Price/Book Value Ratio - Current (Security)                               0.016711
# Price/Cash Flow Current (Security)                                        0.028485
# Price/Earnings Ratio - Current (Security)                                 0.024378
# Return On Equity - Per Share - Current                                    0.026005
#
#                                              Market Price - Current (Security)  \
# Indicated Dividend Rate (Security)                                    0.943762
# Alpha (Security)                                                     -0.004778
# Beta (WS)                                                             0.004430
# Book Value Per Share - Current (Security)                             0.908427
# Cash Flow Per Share - Current (Security)                              0.861247
# Earnings Yield - Current (Security)                                   0.014514
# Market Capitalization Current (U.S.$)                                 0.136397
# Market Price - Current (Security)                                     1.000000
# Price/Book Value Ratio - Current (Security)                           0.004933
# Price/Cash Flow Current (Security)                                    0.007234
# Price/Earnings Ratio - Current (Security)                             0.006983
# Return On Equity - Per Share - Current                                0.008164
#
#                                              Price/Book Value Ratio - Current (Security)  \
# Indicated Dividend Rate (Security)                                              0.006903
# Alpha (Security)                                                                0.214107
# Beta (WS)                                                                      -0.042802
# Book Value Per Share - Current (Security)                                       0.001299
# Cash Flow Per Share - Current (Security)                                        0.005900
# Earnings Yield - Current (Security)                                             0.020019
# Market Capitalization Current (U.S.$)                                           0.016711
# Market Price - Current (Security)                                               0.004933
# Price/Book Value Ratio - Current (Security)                                     1.000000
# Price/Cash Flow Current (Security)                                             -0.134585
# Price/Earnings Ratio - Current (Security)                                      -0.121722
# Return On Equity - Per Share - Current                                         -0.253748
#
#                                              Price/Cash Flow Current (Security)  \
# Indicated Dividend Rate (Security)                                     0.007677
# Alpha (Security)                                                       0.022064
# Beta (WS)                                                             -0.111694
# Book Value Per Share - Current (Security)                              0.004283
# Cash Flow Per Share - Current (Security)                               0.008786
# Earnings Yield - Current (Security)                                    0.025738
# Market Capitalization Current (U.S.$)                                  0.028485
# Market Price - Current (Security)                                      0.007234
# Price/Book Value Ratio - Current (Security)                           -0.134585
# Price/Cash Flow Current (Security)                                     1.000000
# Price/Earnings Ratio - Current (Security)                              0.085539
# Return On Equity - Per Share - Current                                 0.020921
#
#                                              Price/Earnings Ratio - Current (Security)  \
# Indicated Dividend Rate (Security)                                            0.006960
# Alpha (Security)                                                              0.069407
# Beta (WS)                                                                    -0.057886
# Book Value Per Share - Current (Security)                                     0.006082
# Cash Flow Per Share - Current (Security)                                      0.006297
# Earnings Yield - Current (Security)                                           0.009879
# Market Capitalization Current (U.S.$)                                         0.024378
# Market Price - Current (Security)                                             0.006983
# Price/Book Value Ratio - Current (Security)                                  -0.121722
# Price/Cash Flow Current (Security)                                            0.085539
# Price/Earnings Ratio - Current (Security)                                     1.000000
# Return On Equity - Per Share - Current                                        0.007014
#
#                                              Return On Equity - Per Share - Current
# Indicated Dividend Rate (Security)                                         0.023207
# Alpha (Security)                                                           0.074413
# Beta (WS)                                                                 -0.126593
# Book Value Per Share - Current (Security)                                  0.010319
# Cash Flow Per Share - Current (Security)                                   0.008418
# Earnings Yield - Current (Security)                                        0.090090
# Market Capitalization Current (U.S.$)                                      0.026005
# Market Price - Current (Security)                                          0.008164
# Price/Book Value Ratio - Current (Security)                               -0.253748
# Price/Cash Flow Current (Security)                                         0.020921
# Price/Earnings Ratio - Current (Security)                                  0.007014
# Return On Equity - Per Share - Current                                     1.000000

# %%
# refer to multiple regression file

# %%
# Multiple Regression

#import os
#os.chdir(os.environ['USERPROFILE'] + '\Documents' + r"\0_Teach\data") # change "\0_Teach\data" accordingly
import pandas as pd
from statsmodels.formula.api import ols

#h = pd.read_csv(r"HDB_Data500.csv", index_col=0) #use 1st column as row labels
#h = h.iloc[:, 1:6] #retain only the 2nd to 6th column
h = newdf
import re 
h = h.rename(columns=lambda x: re.sub('\W', '_', x))

print('\nThe dataset has', len(h), 'rows and', h.shape[1], 'columns.') #len(h) == h.shape[0]

print('\nColumns are:', list(h))

modeleq = ' + '.join(list(h)).replace('+', '~', 1)
#takes the columns names, put into a list. 
#working on this list, joining the individual ones with a plus sign.
#replace the first plus sign with a squiggly sign. 

#can also be written out in full:
#modeleq = 'resale_price ~ storey_range_lower + storey_range_upper + floor_area_sqm + lease_commence_year'

print('\nModel equation:', modeleq, '\n')

#fit the regression model:
print(ols(modeleq, h).fit().summary2())

#can also be done in 1 line, if dataset is in the current folder:
#ols(' + '.join(list(h)).replace('+','~',1), pd.read_csv(r"HDB_Data500.csv", index_col=0).iloc[:, 1:6]).fit().summary2()
# Out:
# The dataset has 1239 rows and 12 columns.
#
# Columns are: ['Indicated_Dividend_Rate__Security_', 'Alpha__Security_', 'Beta__WS_', 'Book_Value_Per_Share___Current__Security_', 'Cash_Flow_Per_Share___Current__Security_', 'Earnings_Yield___Current__Security_', 'Market_Capitalization_Current__U_S___', 'Market_Price___Current__Security_', 'Price_Book_Value_Ratio___Current__Security_', 'Price_Cash_Flow_Current__Security_', 'Price_Earnings_Ratio___Current__Security_', 'Return_On_Equity___Per_Share___Current']
#
# Model equation: Indicated_Dividend_Rate__Security_ ~ Alpha__Security_ + Beta__WS_ + Book_Value_Per_Share___Current__Security_ + Cash_Flow_Per_Share___Current__Security_ + Earnings_Yield___Current__Security_ + Market_Capitalization_Current__U_S___ + Market_Price___Current__Security_ + Price_Book_Value_Ratio___Current__Security_ + Price_Cash_Flow_Current__Security_ + Price_Earnings_Ratio___Current__Security_ + Return_On_Equity___Per_Share___Current
#
#                               Results: Ordinary least squares
# ============================================================================================
# Model:                  OLS                                  Adj. R-squared:       0.944
# Dependent Variable:     Indicated_Dividend_Rate__Security_   AIC:                  2933.9410
# Date:                   2020-04-09 16:23                     BIC:                  2986.6239
# No. Observations:       596                                  Log-Likelihood:       -1455.0
# Df Model:               11                                   F-statistic:          917.3
# Df Residuals:           584                                  Prob (F-statistic):   0.00
# R-squared:              0.945                                Scale:                7.8846
# --------------------------------------------------------------------------------------------
#                                              Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# --------------------------------------------------------------------------------------------
# Intercept                                   -0.0757   0.1735  -0.4364 0.6627 -0.4164  0.2650
# Alpha__Security_                             0.0189   0.0437   0.4317 0.6661 -0.0670  0.1048
# Beta__WS_                                    0.0611   0.1446   0.4224 0.6729 -0.2230  0.3452
# Book_Value_Per_Share___Current__Security_   -0.0108   0.0006 -18.6262 0.0000 -0.0119 -0.0096
# Cash_Flow_Per_Share___Current__Security_     0.0017   0.0036   0.4796 0.6317 -0.0053  0.0087
# Earnings_Yield___Current__Security_         -0.0001   0.0007  -0.0761 0.9394 -0.0014  0.0013
# Market_Capitalization_Current__U_S___        0.0000   0.0000   5.3745 0.0000  0.0000  0.0000
# Market_Price___Current__Security_            0.0162   0.0005  33.3473 0.0000  0.0153  0.0172
# Price_Book_Value_Ratio___Current__Security_ -0.0098   0.0306  -0.3207 0.7486 -0.0698  0.0502
# Price_Cash_Flow_Current__Security_          -0.0002   0.0014  -0.1760 0.8603 -0.0029  0.0024
# Price_Earnings_Ratio___Current__Security_   -0.0001   0.0008  -0.0911 0.9274 -0.0016  0.0015
# Return_On_Equity___Per_Share___Current       0.0002   0.0031   0.0506 0.9596 -0.0060  0.0063
# --------------------------------------------------------------------------------------------
# Omnibus:                      635.057              Durbin-Watson:                 2.012
# Prob(Omnibus):                0.000                Jarque-Bera (JB):              374619.424
# Skew:                         3.975                Prob(JB):                      0.000
# Kurtosis:                     125.565              Condition No.:                 8826505
# ============================================================================================
# * The condition number is large (9e+06). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
# just further reducing the model size here since there are gonna be cubes and cuberoots 
newdf2 = df[['Indicated Dividend Rate (Security)',
        'Alpha (Security)', 'Beta (WS)',
       'Book Value Per Share - Current (Security)',
       'Cash Flow Per Share - Current (Security)',
         'Earnings Yield - Current (Security)',
        'Market Capitalization Current (U.S.$)']]

newdf3 = df[['Indicated Dividend Rate (Security)',
            'Market Price - Current (Security)',
        'Price/Book Value Ratio - Current (Security)',
       'Price/Cash Flow Current (Security)',
       'Price/Earnings Ratio - Current (Security)',
        'Return On Equity - Per Share - Current']]

import re 
newdf2 = newdf2.rename(columns=lambda x: re.sub('\W', '_', x))
newdf3 = newdf3.rename(columns=lambda x: re.sub('\W', '_', x))

# %%
# refer to class 04 file

# %%
#import pandas as pd 
#df = pd.read_stata(r'https://stats.idre.ucla.edu/stat/stata/dae/binary.dta')


#set gre as Y
y = 'Indicated_Dividend_Rate__Security_'
#colname = list(df)
#colname.insert(0,colname.pop(colname.index(y)))
#print(colname)
#df = df[colname]

#transform all Xs into cube & cube-root, using np.cbrt()
import numpy as np
for i in list(newdf2)[1:]: #for each of variables except the first one. dont want to squareroot the y. list(df) is the names of columns. 
    newdf2[i + '_cube'] = newdf2[i] ** 3. #to make it into decimal put dot 
    newdf2[i + '_curt'] = np.cbrt(newdf2[i]) #for cube root is impt to use np.cuberoot or sth. if just say raise to power of one third sometimes wont work. 
# ** (1./3.) should work. but some numbers may not work. 

newdf02 = newdf2.copy() #if dont put copy, will just replace. dont manipulate the dataset. 

colname = list(newdf2)
modeleq = ' + '.join(colname).replace('+', '~', 1)

maxr2 = -np.inf
bmodeleq = modeleq 
numx = newdf2.shape[1] - 1 #not counting y. so minus 1. 

print(modeleq)

from statsmodels.formula.api import ols 

while True: 
    regout = ols(modeleq, newdf2).fit()
    r2 = regout.rsquared_adj 
    if r2 > maxr2: 
        maxr2 = r2
        bmodeleq = modeleq 
    print('adj r2 =', r2, 'for', numx, 'Xs.')
    
    if numx == 1:
        break 
    
    t = regout.tvalues[1:]
    xdrop = list(t[abs(t)==min(abs(t))].index)[0] #smallest t is lousiest t = coeff/SE 
    
    print('Variable to drop:', xdrop)
    
    newdf2.drop([xdrop], axis = 1, inplace=True) 
    colname = list(newdf2)
    modeleq = '+'.join(colname).replace('+', '~', 1)
    
    numx = numx - 1
    
print(ols(bmodeleq, newdf02).fit().summary2()) 
#only drop gpa cube and gpa curt bc the adjusted r squared is the max at 0.161223
# Out:
# Indicated_Dividend_Rate__Security_ ~ Alpha__Security_ + Beta__WS_ + Book_Value_Per_Share___Current__Security_ + Cash_Flow_Per_Share___Current__Security_ + Earnings_Yield___Current__Security_ + Market_Capitalization_Current__U_S___ + Alpha__Security__cube + Alpha__Security__curt + Beta__WS__cube + Beta__WS__curt + Book_Value_Per_Share___Current__Security__cube + Book_Value_Per_Share___Current__Security__curt + Cash_Flow_Per_Share___Current__Security__cube + Cash_Flow_Per_Share___Current__Security__curt + Earnings_Yield___Current__Security__cube + Earnings_Yield___Current__Security__curt + Market_Capitalization_Current__U_S____cube + Market_Capitalization_Current__U_S____curt
# adj r2 = 0.9611362320675573 for 18 Xs.
# Variable to drop: Earnings_Yield___Current__Security__cube
# adj r2 = 0.9612002580430473 for 17 Xs.
# Variable to drop: Market_Capitalization_Current__U_S____cube
# adj r2 = 0.9856644819905368 for 16 Xs.
# Variable to drop: Earnings_Yield___Current__Security_
# adj r2 = 0.9856886101219506 for 15 Xs.
# Variable to drop: Beta__WS_
# adj r2 = 0.9857118155910206 for 14 Xs.
# Variable to drop: Beta__WS__cube
# adj r2 = 0.9857266761432553 for 13 Xs.
# Variable to drop: Beta__WS__curt
# adj r2 = 0.9857421560421908 for 12 Xs.
# Variable to drop: Market_Capitalization_Current__U_S___
# adj r2 = 0.9857392426537163 for 11 Xs.
# Variable to drop: Alpha__Security__curt
# adj r2 = 0.9857256922935237 for 10 Xs.
# Variable to drop: Alpha__Security__cube
# adj r2 = 0.98573696456835 for 9 Xs.
# Variable to drop: Alpha__Security_
# adj r2 = 0.9838424293643097 for 8 Xs.
# Variable to drop: Earnings_Yield___Current__Security__curt
# adj r2 = 0.9838352900013847 for 7 Xs.
# Variable to drop: Cash_Flow_Per_Share___Current__Security__curt
# adj r2 = 0.983772303801987 for 6 Xs.
# Variable to drop: Market_Capitalization_Current__U_S____curt
# adj r2 = 0.9829592415492526 for 5 Xs.
# Variable to drop: Book_Value_Per_Share___Current__Security__curt
# adj r2 = 0.9771276571470437 for 4 Xs.
# Variable to drop: Cash_Flow_Per_Share___Current__Security_
# adj r2 = 0.9680125682684437 for 3 Xs.
# Variable to drop: Book_Value_Per_Share___Current__Security_
# adj r2 = 0.9612512359377795 for 2 Xs.
# Variable to drop: Book_Value_Per_Share___Current__Security__cube
# adj r2 = 0.8761160347855611 for 1 Xs.
#                                 Results: Ordinary least squares
# ===============================================================================================
# Model:                   OLS                                   Adj. R-squared:        0.986
# Dependent Variable:      Indicated_Dividend_Rate__Security_    AIC:                   2157.8028
# Date:                    2020-04-09 16:23                      BIC:                   2215.1778
# No. Observations:        610                                   Log-Likelihood:        -1065.9
# Df Model:                12                                    F-statistic:           3510.
# Df Residuals:            597                                   Prob (F-statistic):    0.00
# R-squared:               0.986                                 Scale:                 1.9708
# -----------------------------------------------------------------------------------------------
#                                                 Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                                      -1.0224   0.1274  -8.0260 0.0000 -1.2726 -0.7722
# Alpha__Security_                                0.1042   0.0504   2.0662 0.0392  0.0052  0.2033
# Book_Value_Per_Share___Current__Security_      -0.0139   0.0005 -26.2106 0.0000 -0.0149 -0.0129
# Cash_Flow_Per_Share___Current__Security_        0.0281   0.0031   8.9467 0.0000  0.0220  0.0343
# Market_Capitalization_Current__U_S___           0.0000   0.0000   1.0593 0.2899 -0.0000  0.0000
# Alpha__Security__cube                          -0.0000   0.0000  -1.3569 0.1753 -0.0001  0.0000
# Alpha__Security__curt                          -0.1280   0.1046  -1.2234 0.2216 -0.3333  0.0774
# Book_Value_Per_Share___Current__Security__cube  0.0000   0.0000  48.9274 0.0000  0.0000  0.0000
# Book_Value_Per_Share___Current__Security__curt  1.9216   0.1086  17.6948 0.0000  1.7083  2.1349
# Cash_Flow_Per_Share___Current__Security__cube   0.0000   0.0000  51.9640 0.0000  0.0000  0.0000
# Cash_Flow_Per_Share___Current__Security__curt  -0.3171   0.1530  -2.0721 0.0387 -0.6176 -0.0166
# Earnings_Yield___Current__Security__curt       -0.0594   0.0236  -2.5147 0.0122 -0.1058 -0.0130
# Market_Capitalization_Current__U_S____curt     -0.0081   0.0021  -3.8298 0.0001 -0.0122 -0.0039
# -----------------------------------------------------------------------------------------------
# Omnibus:                      944.928               Durbin-Watson:                  2.014
# Prob(Omnibus):                0.000                 Jarque-Bera (JB):               595160.525
# Skew:                         8.478                 Prob(JB):                       0.000
# Kurtosis:                     155.081               Condition No.:                  95659613817
# ===============================================================================================
# * The condition number is large (1e+11). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
#import pandas as pd 
#df = pd.read_stata(r'https://stats.idre.ucla.edu/stat/stata/dae/binary.dta')


#set gre as Y
y = 'Indicated_Dividend_Rate__Security_'
#colname = list(df)
#colname.insert(0,colname.pop(colname.index(y)))
#print(colname)
#df = df[colname]

#transform all Xs into cube & cube-root, using np.cbrt()
import numpy as np
for i in list(newdf3)[1:]: #for each of variables except the first one. dont want to squareroot the y. list(df) is the names of columns. 
    newdf3[i + '_cube'] = newdf3[i] ** 3. #to make it into decimal put dot 
    newdf3[i + '_curt'] = np.cbrt(newdf3[i]) #for cube root is impt to use np.cuberoot or sth. if just say raise to power of one third sometimes wont work. 
# ** (1./3.) should work. but some numbers may not work. 

newdf03 = newdf3.copy() #if dont put copy, will just replace. dont manipulate the dataset. 

colname = list(newdf3)
modeleq = ' + '.join(colname).replace('+', '~', 1)

maxr2 = -np.inf
bmodeleq = modeleq 
numx = newdf3.shape[1] - 1 #not counting y. so minus 1. 

print(modeleq)

from statsmodels.formula.api import ols 

while True: 
    regout = ols(modeleq, newdf3).fit()
    r2 = regout.rsquared_adj 
    if r2 > maxr2: 
        maxr2 = r2
        bmodeleq = modeleq 
    print('adj r2 =', r2, 'for', numx, 'Xs.')
    
    if numx == 1:
        break 
    
    t = regout.tvalues[1:]
    xdrop = list(t[abs(t)==min(abs(t))].index)[0] #smallest t is lousiest t = coeff/SE 
    
    print('Variable to drop:', xdrop)
    
    newdf3.drop([xdrop], axis = 1, inplace=True) 
    colname = list(newdf3)
    modeleq = '+'.join(colname).replace('+', '~', 1)
    
    numx = numx - 1
    
print(ols(bmodeleq, newdf03).fit().summary2()) 
#only drop gpa cube and gpa curt bc the adjusted r squared is the max at 0.161223
# Out:
# Indicated_Dividend_Rate__Security_ ~ Market_Price___Current__Security_ + Price_Book_Value_Ratio___Current__Security_ + Price_Cash_Flow_Current__Security_ + Price_Earnings_Ratio___Current__Security_ + Return_On_Equity___Per_Share___Current + Market_Price___Current__Security__cube + Market_Price___Current__Security__curt + Price_Book_Value_Ratio___Current__Security__cube + Price_Book_Value_Ratio___Current__Security__curt + Price_Cash_Flow_Current__Security__cube + Price_Cash_Flow_Current__Security__curt + Price_Earnings_Ratio___Current__Security__cube + Price_Earnings_Ratio___Current__Security__curt + Return_On_Equity___Per_Share___Current_cube + Return_On_Equity___Per_Share___Current_curt
# adj r2 = 0.8967262075040042 for 15 Xs.
# Variable to drop: Return_On_Equity___Per_Share___Current
# adj r2 = 0.8968665247690173 for 14 Xs.
# Variable to drop: Price_Earnings_Ratio___Current__Security_
# adj r2 = 0.8970046421722706 for 13 Xs.
# Variable to drop: Price_Earnings_Ratio___Current__Security__cube
# adj r2 = 0.8971443118061398 for 12 Xs.
# Variable to drop: Price_Earnings_Ratio___Current__Security__curt
# adj r2 = 0.8972764971031938 for 11 Xs.
# Variable to drop: Price_Book_Value_Ratio___Current__Security__cube
# adj r2 = 0.8974056141392014 for 10 Xs.
# Variable to drop: Return_On_Equity___Per_Share___Current_cube
# adj r2 = 0.8975330221002012 for 9 Xs.
# Variable to drop: Return_On_Equity___Per_Share___Current_curt
# adj r2 = 0.8976238649077929 for 8 Xs.
# Variable to drop: Price_Cash_Flow_Current__Security__cube
# adj r2 = 0.8977084745448489 for 7 Xs.
# Variable to drop: Price_Book_Value_Ratio___Current__Security_
# adj r2 = 0.8977926381533363 for 6 Xs.
# Variable to drop: Price_Cash_Flow_Current__Security_
# adj r2 = 0.897854211856173 for 5 Xs.
# Variable to drop: Price_Book_Value_Ratio___Current__Security__curt
# adj r2 = 0.8977856046052997 for 4 Xs.
# Variable to drop: Price_Cash_Flow_Current__Security__curt
# adj r2 = 0.8976471710167179 for 3 Xs.
# Variable to drop: Market_Price___Current__Security__cube
# adj r2 = 0.8969303249532118 for 2 Xs.
# Variable to drop: Market_Price___Current__Security__curt
# adj r2 = 0.8905450357418605 for 1 Xs.
#                                 Results: Ordinary least squares
# ================================================================================================
# Model:                  OLS                                    Adj. R-squared:         0.898
# Dependent Variable:     Indicated_Dividend_Rate__Security_     AIC:                    4038.2999
# Date:                   2020-04-09 16:23                       BIC:                    4066.1548
# No. Observations:       767                                    Log-Likelihood:         -2013.1
# Df Model:               5                                      F-statistic:            1348.
# Df Residuals:           761                                    Prob (F-statistic):     0.00
# R-squared:              0.899                                  Scale:                  11.239
# ------------------------------------------------------------------------------------------------
#                                                   Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                                         0.3384   0.2578  1.3128 0.1897 -0.1676  0.8444
# Market_Price___Current__Security_                 0.0112   0.0006 18.0906 0.0000  0.0100  0.0124
# Market_Price___Current__Security__cube            0.0000   0.0000  2.1922 0.0287  0.0000  0.0000
# Market_Price___Current__Security__curt           -0.7219   0.1565 -4.6116 0.0000 -1.0292 -0.4146
# Price_Book_Value_Ratio___Current__Security__curt  0.2700   0.2196  1.2296 0.2192 -0.1611  0.7012
# Price_Cash_Flow_Current__Security__curt           0.0769   0.0535  1.4387 0.1506 -0.0280  0.1819
# ------------------------------------------------------------------------------------------------
# Omnibus:                      921.375               Durbin-Watson:                  1.967
# Prob(Omnibus):                0.000                 Jarque-Bera (JB):               1148255.739
# Skew:                         4.944                 Prob(JB):                       0.000
# Kurtosis:                     192.293               Condition No.:                  655669293281
# ================================================================================================
# * The condition number is large (7e+11). This might indicate             strong
# multicollinearity or other numerical problems.

# %%
df = newdf2
y = 'Indicated_Dividend_Rate__Security_'
trf = ['_cube', '_cbrt'] #may be adapted for square & square-root

import numpy as np

for i in list(df)[1:]:
    #try:
    df[i + trf[0]] = df[i] ** (3. if '_cube' in trf else 2.)
    df[i + trf[1]] = np.cbrt(df[i]) if '_cube' in trf else np.sqrt(df[i])
    #except:
        #column cannot be transformed
        #delete non-numeric column (with no questions asked!):
    #df.drop(i, axis=1, inplace=True)

#only numeric columns left
df0 = df.copy() #kept for inclusion of interaction variables later
    
#perform feature selection using adjusted R2

modeleq = ' + '.join(list(df)).replace('+', '~', 1)
#print(modeleq)
maxR2 = -np.inf
bmodeleq = modeleq
numx = df.shape[1] - 1
x1x2 = False #interaction variables not yet included

from statsmodels.formula.api import ols

while True:
    regout = ols(modeleq, df).fit()
    R2 = regout.rsquared_adj
    #see if a better model is found:
    if R2 > maxR2:
        maxR2 = R2
        bmodeleq = modeleq

    print('\nAdjusted R2 =', R2, 'for', numx, 'Xs.')

    if numx == 1:
        print('Variable left:', modeleq[modeleq.find('~') + 2 :])
        if x1x2:
            #one xvar left
            #get out of 'while' loop:
            break
            
        else:
            #add interaction variables for original untransformed variables in best model so far
            
            numx = bmodeleq.count('+') + 1
            print('\nRestarting from best model (with', numx, 'Xs) found so far...')
            
            colname = bmodeleq.replace('~', '+').split(' + ')
            df = df0[colname]
            colname = colname[1:] #remove y
            
            for i in range(numx):
                #look for 1st transformed variable:
                if colname[i][-5:] in trf:
                    i = i - 1
                    #colname[i] is the last untransformed x
                    break
            
            print('\nAdding', int((i + 1) * i / 2), '2-way interactions among', i + 1,
                  'untransformed variables in best model found so far:')
            for j in range(i):
                #untransformed x in colname up to [i]
                for k in range(j + 1, i + 1):
                    a = colname[j] + '_x_' + colname[k]
                    print(a)
                    df[a] = df[colname[j]] * df[colname[k]]
                    
            df0 = df.copy()
                    
            #delete any x too highly correlated with another x, to avoid collinearity
            
            corv = pd.DataFrame() #start empty dataframe for corr(Xs, y) to come
            for x in list(df)[1:]:
                #during 1st time thru loop, new column, with label, created in empty dataframe
                corv.loc[x, y] = df[x].corr(df[y]) #new entry, with row label, added to dataframe
                
            corv = corv.loc[abs(corv).sort_values([y]).index, :] #corr(Xs, y) ranked

            delta = 0.005 #corr difference lower limit
            dl2 = []
            icorr = True
            while icorr:
                a = abs(corv).diff() <= delta #adjacent rows with similar abs(corr(Xs, y))
                colname = list(df)[1:]
                dl = []
                print('\nX pairs with correlations >', 1 - delta, ':')
                for b in range(1, a.shape[0]):
                    if a.iloc[b, 0]:
                        if abs(df[a.index[b - 1]].corr(df[a.index[b]])) > 1 - delta:
                            #deleting 1 X from correlated pair:
                            dv0 = a.index[b - 1]
                            dv1 = a.index[b]

                            #neither should already be deleted:
                            if not (dv0 in dl) and not (dv1 in dl):
                                #delete x with rather lower corr(x, y):
                                if abs(corv.loc[dv0, y]) - abs(corv.loc[dv1, y]) >= delta:
                                    d = dv1
                                elif len(dv0) < len(dv1): #delete x with longer name:
                                    d = dv1
                                else:
                                    d = dv0
                                    
                                dl.append(d) #for en masse deletion later
                                corv.drop([d], axis=0, inplace=True) #delete from column of corr with y

                                print(dv0,',',dv1)
            
                if len(dl) > 0:
                    df.drop(axis=1, columns=dl, inplace=True) #variables deleted en masse
                    dl2 = dl2 + dl #keep for real deletion later
                    print('\n' + str(len(dl)), 'variables considered for deletion:')
                    print('\n'.join([str(x) for x in dl]))
                else:
                    print('(no more)')
                    icorr = False
                    
            dl2 = [x for x in dl2 if x.find('_x_') != -1] #only interaction variables kept
            df0.drop(axis=1, columns=dl2, inplace=True) #collinear interaction variables deleted en masse, for real
            #remaining Xs may be collinear
            print('\nOnly', len(dl2), 'interaction variables actually deleted.')
            
            #potential collinearity issues handled
            
            
            modeleq = ' + '.join(list(df0)).replace('+', '~', 1)
            numx = df0.shape[1] - 1
            x1x2 = True #interaction variables already included
            
            #beyond-pairwise collinearity may still be introduced with the interaction variables
            
            df = df0.copy() #ready for continuing deletion
            continue

    #identify X variable to delete by finding the one with smallest abs(t-stat):
    t = regout.tvalues[1:]
    xdrop = list(t[abs(t) == min(abs(t))].index)[0]
    print('Variable to drop:', xdrop)
    
    df.drop(xdrop, axis=1, inplace=True)
    modeleq = ' + '.join(list(df)).replace('+', '~', 1)
    
    numx = numx - 1

print('\nBest model has', bmodeleq.count('+') + 1, 'Xs:')
out = ols(bmodeleq, df0).fit()
#collinearity is still entirely possible at this stage
print(out.summary2())

print("\nDescending order of X's significance:")
print('\n'.join(list(abs(out.tvalues[1:]).sort_values(0, ascending=False).index)))
#if the single best variable isn't high in above ranking, collinearity might be an issue
# Out:
# Adjusted R2 = 0.618943930273461 for 3 Xs.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-832a510e3509> in <module>
#     140     #identify X variable to delete by finding the one with smallest abs(t-stat):
#     141     t = regout.tvalues[1:]
# --> 142     xdrop = list(t[abs(t) == min(abs(t))].index)[0]
#     143     print('Variable to drop:', xdrop)
#     144
#
# IndexError: list index out of range
